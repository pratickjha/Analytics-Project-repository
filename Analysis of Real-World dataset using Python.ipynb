# %% [markdown]
# ## Summary
#
# Analysis of Real-World dataset using SQL and Python

# %%
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/55/74/a3f79e7ed1af6f669f4e630cecc8d672b201fe8cfe5a39c8bd47f4209bf7/SQLAlchemy-1.4.29-cp37-cp37m-win_amd64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/58/fd/f82049e9b21773188a72bd1bc53530b900392808f8b823e4c778e7c035f0/importlib_metadata-4.10.1-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/f5/34/adc2134c9567dd99254f20e6981a9006a5767dfed287eb94f273ec51e092/greenlet-1.1.2-cp37-cp37m-win_amd64.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/52/c5/df7953fe6065185af5956265e3b16f13c2826c2b1ba23d43154f3af453bc/zipp-3.7.0-py3-none-any.whl
# ...
#   Using cached https://files.pythonhosted.org/packages/05/e4/baf0031e39cf545f0c9edd5b1a2ea12609b7fcba2d58e118b11753d68cf0/typing_extensions-4.0.1-py3-none-any.whl
# ...
#   Found existing installation: ibm-db 3.1.0
#     Uninstalling ibm-db-3.1.0:
# ...

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql ibm_db_sa://xqk06680:B9aecRgnyF2754zQ@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB;security=SSL;

# %%
import pandas as pd
chicago_socioeconomic_data = pd.read_csv('https://data.cityofchicago.org/resource/jcxq-k9xf.csv')
# %sql --persist chicago_socioeconomic_data
# Out:
#  * ibm_db_sa://xqk06680:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB;security=SSL;
# 'Persisted chicago_school_report_card'

# %% [markdown]
# ## check no of rows by running a query

# %%
# %sql select * from chicago_socioeconomic_data;
# Out:
#  * ibm_db_sa://xqk06680:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB;security=SSL;
# Done.
# [(0, 1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (1, 2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (2, 3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (3, 4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (4, 5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0),
#  (5, 6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0),
#  (6, 7.0, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2.0),
#  (7, 8.0, 'Near North Side', 1.9, 12.9, 7.0, 2.5, 22.6, 88669, 1.0),
#  (8, 9.0, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8.0),
#  (9, 10.0, 'Norwood Park', 2.0, 5.4, 9.0, 11.5, 39.5, 32875, 21.0),
#  (10, 11.0, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25.0),
#  (11, 12.0, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11.0),
# ...

# %%
# %sql select count(*) from chicago_socioeconomic_data;
# Out:
#  * ibm_db_sa://xqk06680:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB;security=SSL;
# Done.
# [(78,)]

# %%
# %sql select count(*) from chicago_socioeconomic_data where hardship_index>50.0;
# Out:
#  * ibm_db_sa://xqk06680:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB;security=SSL;
# Done.
# [(38,)]

# %%
# %sql select community_area_name,hardship_index from chicago_socioeconomic_data where hardship_index=(select max(hardship_index) from chicago_socioeconomic_data);
# Out:
#  * ibm_db_sa://xqk06680:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB;security=SSL;
# Done.
# [('Riverdale', 98.0)]

# %%
# %sql select community_area_name from chicago_socioeconomic_data where per_capita_income_ >60000;
# Out:
#  * ibm_db_sa://xqk06680:***@0c77d6f2-5da9-48a9-81f8-86b520b87518.bs2io90l08kqb1od8lcg.databases.appdomain.cloud:31198/BLUDB;security=SSL;
# Done.
# [('Lake View',), ('Lincoln Park',), ('Near North Side',), ('Loop',)]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plot = sns.scatterplot(x='per_capita_income_',y='hardship_index',data =chicago_socioeconomic_data)
